# %% [markdown]
# ## Yoshops Data Science Internship Project Task 5 : Using webscraping, do analysis of mobiles and laptops in website https://www.reliancedigital.in/ for Budget below Rs.10000
#
# ## <u>Name</u> : ADVAIT GURUNATH CHAVAN
# ## <u>Contact No.</u>: +91 70214 55852
# ## <u>Email ID</u> : advaitchavan135@gmail.com  , advaitchavan.yoshops@gmail.com

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
reliance_data_links_csv = pd.read_csv('reliance_digital_mobiles_under_10000_link.csv')

# %%
reliance_data_links_csv
# Out:
#                                      Product_name_link  \
# 0    https://www.reliancedigital.in/itel-a23-pro-8-...
# 1    https://www.reliancedigital.in/itel-a23-pro-8-...
# 2    https://www.reliancedigital.in/jiophone-next-3...
# 3    https://www.reliancedigital.in/tcl-l7-32-gb-2-...
# 4    https://www.reliancedigital.in/itel-a27-32-gb-...
# ..                                                 ...
# 128  https://www.reliancedigital.in/moto-g22-64-gb-...
# 129  https://www.reliancedigital.in/vivo-y16-64-gb-...
# 130  https://www.reliancedigital.in/realme-c33-64-g...
# 131  https://www.reliancedigital.in/vivo-y16-64-gb-...
# 132  https://www.reliancedigital.in/realme-c33-64-g...
#
#                                     Product_price_link
# 0    https://www.reliancedigital.in/itel-a23-pro-8-...
# 1    https://www.reliancedigital.in/itel-a23-pro-8-...
# 2    https://www.reliancedigital.in/jiophone-next-3...
# 3    https://www.reliancedigital.in/tcl-l7-32-gb-2-...
# ...

# %%
import csv
import requests
from bs4 import BeautifulSoup

# Open the CSV file
with open('reliance_digital_mobiles_under_10000_link.csv', 'r') as file:
    # Create a CSV reader object
    csv_reader = csv.reader(file)
    
    # Skip the header row if needed
    next(csv_reader)
    
    # Iterate over each row in the CSV file
    for i, row in enumerate(csv_reader, 1):  # Start the serial number from 1
        # Get the link from the appropriate column
        link = row[0]  # Adjust the column index as per your CSV structure
        
        # Make a request to the link
        response = requests.get(link)
        
        # Check if the request was successful
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Extract the data you need from the parsed HTML using BeautifulSoup
            # Example: Extract the title from the page
            title = soup.title.text
            
            # Do further processing with the extracted data as needed
            print(f"Item Number {i}: {title}")
        else:
            # Handle any errors or unsuccessful requests
            print(f"Error accessing link in row {i}: {link}")
# Out:
# Item Number 1: Buy itel A23 Pro 8 GB, 1 GB RAM, Lake Blue, Mobile Phone at Best Price on Reliance Digital
# Item Number 2: Buy itel A23 Pro 8 GB, 1 GB RAM, Sapphire Blue, Mobile Phone at Best Price on Reliance Digital
# Item Number 3: Buy JioPhone Next 32 GB, 2 GB RAM, Blue Smartphone, LS1542QWN at Reliance Digital
# Item Number 4: Buy TCL L7 32 GB, 2 GB RAM, Black, Mobile Phone at Reliance Digital
# Item Number 5: Buy Itel A27 32 GB, 2 GB RAM, Silver Purple, Mobile Phone at Reliance Digital
# Item Number 6: Buy Itel A27 32 GB, 2 GB RAM, Deep Grey, Mobile Phone at Reliance Digital
# Item Number 7: Buy Samsung Galaxy M01 Core 16 GB, 1 GB, Red, Mobile Phone at Reliance Digital
# Item Number 8: Buy Nokia C01 Plus 16 GB, 2 GB RAM, Grey, Mobile Phone (JioExclusive offer available) at Reliance Digital
# Item Number 9: Buy Redmi A1 32 GB, 2 GB RAM, Light Blue Mobile Phone at Best Price on Reliance Digital
# ...

# %%
reliance_mobiles_under_10k = pd.read_csv('Reliance_Digital_Mobile_phones_under_10000_brand.csv')

# %%
reliance_mobiles_under_10k
# Out:
#                                          Product_title  Product_Price  \
# 0         Redmi A1 32 GB, 2 GB RAM, Black Mobile Phone           5949
# 1    Redmi A1 Plus 32 GB, 3 GB RAM, Black Mobile Phone           7499
# 2    Redmi A1 Plus 32 GB, 2 GB RAM, Light Green Mob...           6499
# 3    Redmi A1 32 GB, 2 GB RAM, Light Green Mobile P...           5949
# 4    Redmi A1 Plus 32 GB, 3 GB RAM, Light Green Mob...           7499
# ..                                                 ...            ...
# 126  Moto g22 64 GB, 4 GB RAM, Cosmic Black, Mobile...           9999
# 127  Moto g22 64 GB, 4 GB RAM, Iceberg Blue, Mobile...           9999
# 128  Motorola E32s 64 GB, 4 GB RAM, Misty Silver, M...           9999
# 129  Moto g22 64 GB, 4 GB RAM, Mint Green, Mobile P...           9999
# 130  JioPhone Next 32 GB, 2 GB RAM, Blue Smartphone...           4499
#
#     Product_brand_name
# 0               Xiaomi
# 1               Xiaomi
# 2               Xiaomi
# 3               Xiaomi
# ...

# %%
# Read the CSV file into a DataFrame
df = reliance_mobiles_under_10k

# Analyze the data
#Counting the number of occurrences for each brand
brand_counts = df['Product_brand_name'].value_counts()
print("Brand Counts:")
print(brand_counts)
# Out:
# Brand Counts:
# Xiaomi      36
# Realme      24
# Samsung     14
# Nokia       13
# Itel        12
# Motorola     8
# VIVO         7
# Tecno        7
# Oppo         7
# TCL          1
# POCO         1
# JIO          1
# Name: Product_brand_name, dtype: int64

# %%
# Calculating the average price by brand
average_prices = df.groupby('Product_brand_name')['Product_Price'].mean()
print("Average Prices by Brand:")
print(average_prices)
# Out:
# Average Prices by Brand:
# Product_brand_name
# Itel        6268.333333
# JIO         4499.000000
# Motorola    9624.000000
# Nokia       7652.846154
# Oppo        9566.571429
# POCO        8499.000000
# Realme      8711.500000
# Samsung     8691.857143
# TCL         4999.000000
# Tecno       8956.142857
# VIVO        9353.571429
# Xiaomi      7875.555556
# Name: Product_Price, dtype: float64

# %%
# Find the most expensive product
max_price = df['Product_Price'].max()
most_expensive_product = df.loc[df['Product_Price'] == max_price, 'Product_title'].iloc[0]
print("Most Expensive Product:")
print(most_expensive_product)
# Out:
# Most Expensive Product:
# Redmi 10 64 GB, 4 GB RAM, Midnight Black, Mobile Phone

# %%
# Filter products based on a condition
filtered_products = df.loc[df['Product_Price'] > 5000]  # Filter products with price > 5000
print("Filtered Products:")
print(filtered_products)
# Out:
# Filtered Products:
#                                          Product_title  Product_Price  \
# 0         Redmi A1 32 GB, 2 GB RAM, Black Mobile Phone           5949
# 1    Redmi A1 Plus 32 GB, 3 GB RAM, Black Mobile Phone           7499
# 2    Redmi A1 Plus 32 GB, 2 GB RAM, Light Green Mob...           6499
# 3    Redmi A1 32 GB, 2 GB RAM, Light Green Mobile P...           5949
# 4    Redmi A1 Plus 32 GB, 3 GB RAM, Light Green Mob...           7499
# ..                                                 ...            ...
# 125  Motorola E7 Power 64 GB, 4 GB RAM, Digital Blu...           8999
# 126  Moto g22 64 GB, 4 GB RAM, Cosmic Black, Mobile...           9999
# 127  Moto g22 64 GB, 4 GB RAM, Iceberg Blue, Mobile...           9999
# 128  Motorola E32s 64 GB, 4 GB RAM, Misty Silver, M...           9999
# 129  Moto g22 64 GB, 4 GB RAM, Mint Green, Mobile P...           9999
#
#     Product_brand_name
# 0               Xiaomi
# 1               Xiaomi
# 2               Xiaomi
# ...

# %%
# Bar plot of brand counts
brand_counts = df['Product_brand_name'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=brand_counts.index, y=brand_counts.values)
plt.title('Brand Counts')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Bar plot of average prices by brand
average_prices = df.groupby('Product_brand_name')['Product_Price'].mean()
plt.figure(figsize=(10, 6))
sns.barplot(x=average_prices.index, y=average_prices.values)
plt.title('Average Prices by Brand')
plt.xlabel('Brand')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %%
# Scatter plot of brand names and prices
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Product_brand_name', y='Product_Price')
plt.title('Brand Names vs Prices')
plt.xlabel('Brand')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()
