# %% [markdown]
# ## <u>Name</u> : ADVAIT GURUNATH CHAVAN
# ## <u>Email</u> : advaitchavan135@gmail.com , advaitchavan.yoshops@gmail.com
# ## <u>Contact</u> : +91 70214 55852
#
# ## Yoshops Data Science Internship Project Task - 9 : Digital Marketing Automation
#
# ## Create python program for generating banner, video,blog word file,post Text file
# ## A. Create Banner(Jpg,Png),Tag Line for topic(notepad),Topic description  file(notepad),keyword file(notepad)
#
# ## B. Create 200sec 🎥   shorts videos(MP4) on Data Science Basic Training Program for Everyone.
#
# ## C. Write a blog on Data Science Basic Training Program for Everyone.
#
# ## D. Create a post for LinkedIn(Account) on Data Science Basic Training Program for Everyone.(Text File)
#
# ## E. Create 4 offer banner and poster(Jpg,Png) on Data Science Basic Training Program for Everyone.

# %% [markdown]
# ### A. Create Banner(Jpg,Png),Tag Line for topic(notepad),Topic description file(notepad),keyword file(notepad)

# %%
import requests
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import numpy as np
import pandas as pd
from PIL import Image,ImageFont, ImageDraw
from moviepy.editor import AudioFileClip, ImageClip
import cv2
import os
from os.path import isfile, join
import docx
import sys
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import moviepy.editor as mp

# %%
img = Image.open('sample-2.jpg')
plt.imshow(img)

# %%
img = Image.open('sample-2.jpg')
img2 = Image.open('logo.jpg')
final_img = img.copy()
draw = ImageDraw.Draw(final_img)
font1 = ImageFont.truetype('arial.ttf', 80)
font2 = ImageFont.truetype('arial.ttf', 40)
font3 = ImageFont.truetype('arial.ttf', 50)
#draw.text((50,50),"Data Science", (0,255,255), font=font1, stroke_width=2)
draw.text((50,30),"Training",(255,238,230), font=font1, stroke_width=2)
draw.text((50,130),"& Internship Program",(255,238,230), font=font1, stroke_width=2)
draw.text((1400,600),"Contact:",(255,187,51), font=font3, stroke_width=2)
draw.text((1400,690),"Website: https://yoshops.com/",(204,255,255), font=font2, stroke_width=1)
draw.text((1400,750),"Email: info@yoshops.com",(204,255,255), font=font2, stroke_width=1)
draw.text((1400,810),"Mobile: +91 9080749858",(204,255,255), font=font2, stroke_width=1)
final_img.paste(img2, (850,10))
plt.imshow(final_img)

# %%
final_img.save('data_science_training_program.jpg')
final_img.save('data_science_training_program.png')

# %%
from PIL import Image, ImageDraw, ImageFont

# Banner
banner_text = "Data Science Basic Training Program"
banner_color = (0, 128, 255)  # RGB color (blue)
banner_size = (800, 200)  # Width, Height in pixels
font_path = "arial.ttf"  # Replace with the path to your desired font file

# Tagline
tagline = "Unlock the Power of Data: Join Our Basic Training Program for All Ages"

# Topic Description
title = "Data Science Basic Training Program for Everyone (Age 10 to 60)"
description = "Our comprehensive data science basic training program is designed for individuals of all ages, from 10 to 60 years old. Whether you're a student, professional, or retiree, this program will equip you with the fundamental knowledge and skills needed to embark on a successful data science journey. Join us and discover the fascinating world of data science as we cover key concepts, techniques, and applications that are essential in today's data-driven world. No prior experience required!"

# Keywords
keywords = [
    "Data science",
    "Training program",
    "Basic",
    "All ages",
    "10 to 60",
    "Student",
    "Professional",
    "Retiree",
    "Fundamental knowledge",
    "Skills",
    "Data-driven",
    "Concepts",
    "Techniques",
    "Applications",
    "No prior experience"
]

# Create banner image
banner_image = Image.new("RGB", banner_size, color=banner_color)
draw = ImageDraw.Draw(banner_image)
font = ImageFont.truetype(font_path, size=48)
text_width, text_height = draw.textsize(banner_text, font=font)
text_position = ((banner_size[0] - text_width) // 2, (banner_size[1] - text_height) // 2)
draw.text(text_position, banner_text, fill="white", font=font)

# Save banner image
banner_image.save("banner_2.jpg")

# Write tagline to a text file
with open("tagline.txt", "w") as file:
    file.write(tagline)

# Write topic description to a text file
with open("topic_description.txt", "w") as file:
    file.write(f"Title: {title}\n")
    file.write(f"Description: {description}")

# Write keywords to a text file
with open("keywords.txt", "w") as file:
    file.write("\n".join(keywords))

# %% [markdown]
# ### B. Create 200sec 🎥 shorts videos(MP4) on Data Science Basic Training Program for Everyone.

# %%
video_url = "https://yoshops.com/products?keywords=data+science"
video_uClient = uReq(video_url)
video_page_html = video_uClient.read()
video_uClient.close()
video_page_soup = soup(video_page_html,"html.parser")

video_containers = video_page_soup.findAll("div", {"class":"col-sm-3 col-xs-6"})

video_container =  video_containers[0]
image1_link_video = video_container.img['src']
im1 = Image.open(requests.get(image1_link_video, stream=True).raw)
im1.save(r"C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\videoimages\im3.webp")

video_container =  video_containers[1]
image2_link_video = video_container.img['src']
im2 = Image.open(requests.get(image2_link_video, stream=True).raw)
im2.save(r"C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\videoimages\im4.webp")


#Making video from images
width = 1280
height = 720
channel = 3
fps = 1
sec = 200
fourcc = cv2.VideoWriter_fourcc(*'MP42')
video = cv2.VideoWriter('video.mp4', fourcc, float(fps), (width, height))

directory = r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\videoimages'
img_name_list = os.listdir(directory)
for frame_count in range(fps*sec):
    img_name = np.random.choice(img_name_list)
    img_path = os.path.join(directory, img_name)
    img = cv2.imread(img_path)
    img_resize = cv2.resize(img, (width, height))
    video.write(img_resize)
video.release()

# %% [markdown]
# ### C. Write a blog on Data Science Basic Training Program for Everyone.

# %%
from bs4 import BeautifulSoup
import requests
from PIL import Image
import docx

# %%
url = "https://yoshops.com/products/data-science-basic-training-program-for-everyone-age-10-t0-60"
uClient = uReq(url)
page_html = uClient.read()
uClient.close()
page_soup = soup(page_html,"html.parser")
#Extracting image of the product
containers1 = page_soup.findAll("div", {"class":"col-sm-4 single-product-img-col"})
container1 =  containers1[0]
image_link = container1.div.img['src']
im = Image.open(requests.get(image_link, stream=True).raw)
im.save(r"C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Blog\logo-1.webp")
heading = container1.div.img['alt']
containers2 = page_soup.findAll("div", {"class":"col-sm-5"})
container2 =  containers2[0]
available = container2.findAll("font",{"color":"#000000"})
heading = container2.findAll("h1",{"class":"single-product-title"})
containers3 = page_soup.findAll("div", {"class":"col-sm-3"})
container3 =  containers3[0]
price = container3.findAll("span",{"id":"regular-price"})
old_price=price[0].text
dis_price = container3.findAll("span",{"id":"sale-price"})
new_price=dis_price[0].text

mydoc = docx.Document()

mydoc.add_heading(heading[0].text, 0)

mydoc.add_picture(r"C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\videoimages\data_science_training_program.png", width=docx.shared.Inches(6
), height=docx.shared.Inches(5))

mydoc.add_heading("Available Feature", 1)
mydoc.add_paragraph(available[0].text)
mydoc.add_paragraph(available[1].text)
mydoc.add_heading(available[2].text,2)
mydoc.add_heading(available[3].text,1)

mydoc.add_paragraph(available[4].text)
mydoc.add_heading(available[5].text,1)
mydoc.add_paragraph(available[6].text)
mydoc.add_heading(available[7].text,1)
mydoc.add_paragraph(available[8].text)
mydoc.add_heading(available[9].text,1)
mydoc.add_paragraph(available[10].text)
mydoc.add_heading(available[11].text,1)
mydoc.add_paragraph(available[12].text)
mydoc.add_paragraph(available[13].text)
mydoc.add_paragraph(available[14].text)
#mydoc.add_paragraph(available[15].text)
#mydoc.add_paragraph(available[16].text)
#mydoc.add_paragraph(available[17].text)
#mydoc.add_paragraph(available[18].text)
#mydoc.add_paragraph(available[19].text)
#mydoc.add_paragraph(available[20].text)
#mydoc.add_paragraph(available[21].text)
#mydoc.add_paragraph(available[22].text)
#mydoc.add_paragraph(available[23].text)
#mydoc.add_paragraph(available[24].text)
#mydoc.add_paragraph(available[25].text)
#mydoc.add_paragraph(available[26].text)

#mydoc.add_heading(available[27].text, 1)
#mydoc.add_paragraph(available[28].text)
#mydoc.add_paragraph(available[29].text)
#mydoc.add_paragraph(available[30].text)
#mydoc.add_paragraph(available[31].text)
#mydoc.add_paragraph(available[32].text)

#mydoc.save("E:/Yoshops/task_4/my_written_file.docx")
mydoc.save("Blog.docx")

# %% [markdown]
# ### D. Create a post for LinkedIn(Account) on Data Science Basic Training Program for Everyone.(Text File)

# %%
content = """
Exciting news! 📢🎉

I'm thrilled to announce the launch of the Data Science Basic Training Program for Everyone! 🚀🔬

This program is designed to provide a comprehensive introduction to data science, catering to individuals of all ages from 10 to 60. Whether you're a beginner or have some prior knowledge, this training program will equip you with the essential skills and knowledge needed in the field of data science.

📌 Program Highlights:
- Hands-on learning experience with real-world datasets
- Comprehensive curriculum covering data analysis, machine learning, and more
- Expert instructors and mentors to guide you throughout the program
- Flexible schedule to accommodate learners of all ages

Don't miss out on this incredible opportunity to dive into the exciting world of data science! Register now: [Data Science Basic Training Program](https://yoshops.com/products/data-science-basic-training-program-for-everyone-age-10-t0-60)

Feel free to reach out if you have any questions or would like more information. Let's embark on this data science journey together! 🌟💻

#DataScience #TrainingProgram #DataScienceTraining #DataScienceEducation #DataAnalysis #MachineLearning #CareerDevelopment
"""

# Specify the file path for saving the content
file_path = "linkedin_post.txt"

# Save the content to a text file using UTF-8 encoding
with open(file_path, "w", encoding="utf-8") as file:
    file.write(content)

print(f"The LinkedIn post content has been saved to {file_path}.")
# Out:
# The LinkedIn post content has been saved to linkedin_post.txt.

# %% [markdown]
# ### E.Create 4 offer banner and poster(Jpg,Png) on Data Science Basic Training Program for Everyone

# %%
img = Image.open('img_2.jpg')
img2 = Image.open('logo.jpg')
final_img = img.copy()
draw = ImageDraw.Draw(final_img)
font1 = ImageFont.truetype('arial.ttf', 80)
font2 = ImageFont.truetype('arial.ttf', 40)
font3 = ImageFont.truetype('arial.ttf', 50)
#draw.text((50,50),"Data Science", (0,255,255), font=font1, stroke_width=2)
draw.text((300,30),"Training & Internship Program",(255,238,0), font=font1, stroke_width=2)
#draw.text((50,130),"& Internship Program",(255,238,230), font=font1, stroke_width=2)
draw.text((1100,700),"Contact:",(255,187,51), font=font3, stroke_width=2)
draw.text((1100,790),"Website: https://yoshops.com/",(204,255,255), font=font2, stroke_width=1)
draw.text((1100,850),"Email: info@yoshops.com",(204,255,255), font=font2, stroke_width=1)
draw.text((1100,910),"Mobile: +91 9080749858",(204,255,255), font=font2, stroke_width=1)
final_img.paste(img2, (50,10))
plt.imshow(final_img)

# %%
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_1.jpg')
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_1.png')

# %%
img = Image.open('img_3.jpg')
img2 = Image.open('logo.jpg')
final_img = img.copy()
draw = ImageDraw.Draw(final_img)
font1 = ImageFont.truetype('arial.ttf', 180)
font2 = ImageFont.truetype('arial.ttf', 140)
font3 = ImageFont.truetype('arial.ttf', 150)
draw.text((450,90),"Data Science", (0,255,255), font=font1, stroke_width=2)
draw.text((250,250),"Training & Internship Program",(255, 204, 0), font=font1, stroke_width=2)
#draw.text((50,130),"& Internship Program",(255,238,230), font=font1, stroke_width=2)
draw.text((50,600),"Contact:",(204, 51, 0), font=font3, stroke_width=2)
draw.text((50,790),"Website: https://yoshops.com/",(0, 0, 102), font=font2, stroke_width=1)
draw.text((50,920),"Email: info@yoshops.com",(0, 0, 102), font=font2, stroke_width=1)
draw.text((50,1050),"Mobile: +91 9080749858",(0, 0, 102), font=font2, stroke_width=1)
final_img.paste(img2, (50,10))
plt.imshow(final_img)

# %%
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_2.jpg')
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_2.png')

# %%
img = Image.open('img_4.jpg')
img2 = Image.open('logo.jpg')
new_size = (img2.size[0] * 2, img2.size[1] * 2)
img2 = img2.resize(new_size)
final_img = img.copy()
draw = ImageDraw.Draw(final_img)
font1 = ImageFont.truetype('arial.ttf', 180)
font2 = ImageFont.truetype('arial.ttf', 140)
font3 = ImageFont.truetype('arial.ttf', 150)
draw.text((500,90),"Data Science", (0,255,255), font=font1, stroke_width=2)
draw.text((500,250),"Training & Internship Program",(255, 204, 0), font=font1, stroke_width=2)
#draw.text((50,130),"& Internship Program",(255,238,230), font=font1, stroke_width=2)
draw.text((50,2600),"Contact:",(204, 51, 0), font=font3, stroke_width=2)
draw.text((50,2790),"Website: https://yoshops.com/",(0, 0, 102), font=font2, stroke_width=1)
draw.text((50,2920),"Email: info@yoshops.com",(0, 0, 102), font=font2, stroke_width=1)
draw.text((50,3050),"Mobile: +91 9080749858",(0, 0, 102), font=font2, stroke_width=1)
final_img.paste(img2, (50,10))
plt.imshow(final_img)

# %%
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_3.jpg')
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_3.png')

# %%
img = Image.open('img_5.jpg')
img2 = Image.open('logo.jpg')
new_size = (img2.size[0] * 2, img2.size[1] * 2)
img2 = img2.resize(new_size)
final_img = img.copy()
draw = ImageDraw.Draw(final_img)
font1 = ImageFont.truetype('arial.ttf', 180)
font2 = ImageFont.truetype('arial.ttf', 140)
font3 = ImageFont.truetype('arial.ttf', 150)
draw.text((2500,90),"Data Science", (0,255,255), font=font1, stroke_width=2)
draw.text((2500,250),"Training & Internship Program",(255, 204, 0), font=font1, stroke_width=2)
#draw.text((50,130),"& Internship Program",(255,238,230), font=font1, stroke_width=2)
draw.text((50,2600),"Contact:",(204, 51, 0), font=font3, stroke_width=2)
draw.text((50,2790),"Website: https://yoshops.com/",(102, 255, 51), font=font2, stroke_width=1)
draw.text((50,2920),"Email: info@yoshops.com",(102, 255, 51), font=font2, stroke_width=1)
draw.text((50,3050),"Mobile: +91 9080749858",(102, 255, 51), font=font2, stroke_width=1)
final_img.paste(img2, (2000,10))
plt.imshow(final_img)

# %%
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_4.jpg')
final_img.save(r'C:\Users\Advait\Desktop\Yoshops Internships\Project Task - 9\Task E\Banner_4.png')
