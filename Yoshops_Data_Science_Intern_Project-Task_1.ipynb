# %% [markdown]
# # Yoshops Data Science Intern Project Task - 1
# # Python program to extract  product count, product category/subcategory name from an ecommerce website/webpage

# %% [markdown]
# ## <u>Name</u> : ADVAIT GURUNATH CHAVAN
# ## <u>Email Id</u> : advaitchavan135@gmail.com , advaitchavan.yoshops@gmail.com
# ## <u>Contact</u> : +91 70214 55852

# %% [markdown]
# ## Extracting the product count of the main category of the specified link

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = input("Enter the URL of the webpage you want to find the number of products of : ")
#url = 'https://yoshops.com/t/laptops'
# Out:
# Enter the URL of the webpage you want to find the number of products of : https://yoshops.com/t/accessories?page=2

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
response = requests.get(url,headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
x = []
y = []
for i in soup.find_all('div', class_='product-thumb-inner'):
    #print(i)
    x.append(i)
#x = soup.find_all('div', class_='product-thumb-inner')
for j in x:
    y.append(j.find_all('img'))
#a = soup.find_all(class_='breadcrumb')
for i in soup.find_all('ol'):
    b = i.find_all('li')
c=[]
for i in b[1]:
    c.append(i)
print("The number of products in the given url are : ",len(y),"\nThey belong to the category of",c[0],"under Yoshops.com")
print("The number of products available under ",c[0]," are ",len(y))
# Out:
# The number of products in the given url are :  48
# They belong to the category of Accessories under Yoshops.com
# The number of products available under  Accessories  are  48

# %% [markdown]
# ## Extracting the product count of the Subcategory of the specified link

# %%
sub_url = input("Enter the URL of the webpage you want to find the number of products of : ")
#sub_url = 'https://yoshops.com/t/gaming-laptops'
#sub_url = 'https://yoshops.com/t/men-clothing'
# Out:
# Enter the URL of the webpage you want to find the number of products of : https://yoshops.com/t/more

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
response = requests.get(sub_url,headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
x = []
y = []
for i in soup.find_all('div', class_='product-thumb-inner'):
    #print(i)
    x.append(i)
#x = soup.find_all('div', class_='product-thumb-inner')
for j in x:
    y.append(j.find_all('img'))
#a = soup.find_all(class_='breadcrumb')
for i in soup.find_all('ol'):
    b = i.find_all('li')
c=[]
for i in b[2]:
    c.append(i)
for i in soup.find_all('ol'):
    d = i.find_all('a')
e = []
for i in d[1]:
    e.append(i)
print("The number of products in the given url are : ",len(y),"\nThey belong to the Subcategory of",c[0],"under Yoshops.com")
print("The number of products available under ",e[0],">",c[0]," are ",len(y))
# Out:
# The number of products in the given url are :  13
# They belong to the Subcategory of More under Yoshops.com
# The number of products available under  Accessories > More  are  13

# %% [markdown]
# ## Extracting the product count of the Subcategory of Subcategory of the specified link

# %%
sub_sub_url = 'https://yoshops.com/t/men-clothing'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
response = requests.get(sub_sub_url,headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
x = []
y = []
for i in soup.find_all('div', class_='product-thumb-inner'):
    #print(i)
    x.append(i)
#x = soup.find_all('div', class_='product-thumb-inner')
for j in x:
    y.append(j.find_all('img'))
#a = soup.find_all(class_='breadcrumb')
for i in soup.find_all('ol'):
    b = i.find_all('li')
c=[]
for i in b[3]:
    c.append(i)
for i in soup.find_all('ol'):
    d = i.find_all('a')
e = []
for i in d[2]:
    e.append(i)
f = []
for i in d[1]:
    f.append(i)
print("The number of products in the given url are : ",len(y),"\nThey belong to the Sub - Subcategory of",c[0],"\nwhich is a Subcategory of",e[0] ,"\nwhich in turn is a sub category of",f[0],"which is category available under Yoshops.com")
print("The number of products available under ",f[0],">",e[0],">",c[0]," are ",len(y))
# Out:
# The number of products in the given url are :  7
# They belong to the Sub - Subcategory of Men Clothing
# which is a Subcategory of Men
# which in turn is a sub category of Fashion which is category available under Yoshops.com
# The number of products available under  Fashion > Men > Men Clothing  are  7

# %% [markdown]
# ## Finding the product count by giving the user the choice

# %%
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}

print("Welcome to Yoshops.com")
print("\n\nPlease select the correct option finding the number of products on any webpage of Yoshops.com")
print("\n\nEnter 1 if your product lies into the main category of yoshops.com")
print("\n\nEnter 2 if your product lies into the sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat)")
print("\n\nEnter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat>sub_sub_cat)")

choice = int(input("\n\nEnter your choice from the given available options : "))
print("\n\nYou have select option ",choice)

def yoshops_product_count(choice):
    if choice == 1:
        url = input("\n\nEnter the url of the webpage of main category of Yoshops.com : ")
        response = requests.get(url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[1]:
            c.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the category of",c[0],"under Yoshops.com")
        print("The number of products available under ",c[0]," are ",len(y))
        
    elif choice == 2:
        sub_url = input("\n\nEnter the url of the webpage of subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[2]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[1]:
            e.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Subcategory of",c[0],"under Yoshops.com")
        print("The number of products available under ",e[0],">",c[0]," are ",len(y))
        
    elif choice == 3:
        sub_sub_url = input("\n\nEnter the url of the webpage of subcategory under some subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[3]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[2]:
            e.append(i)
        f = []
        for i in d[1]:
            f.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Sub - Subcategory of",c[0],"\nwhich is a Subcategory of",e[0] ,"\nwhich in turn is a sub category of",f[0],"which is category available under Yoshops.com")
        print("The number of products available under ",f[0],">",e[0],">",c[0]," are ",len(y))
        
    else:
        print("\n\nYou have entered a false choice. Please go through the available options and try again")
yoshops_product_count(choice)
# Out:
# Welcome to Yoshops.com
#
#
# Pease select the correct option finding the number of products on any webpage of Yoshops.com
#
#
# Enter 1 if your product lies into the main category of yoshops.com
#
#
# Enter 2 if your product lies into the sub-category of some main category of yoshops.com
# like (main_cat>sub_cat)
#
#
# Enter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com
# like (main_cat>sub_cat>sub_sub_cat)
#
#
# Enter your choice from the given available options : 1
#
#
# You have select option  1
#
#
# Enter the url of the webpage of main category of Yoshops.com : https://yoshops.com/t/laptops
# The number of products in the given url are :  48
# They belong to the category of Laptops under Yoshops.com
# The number of products available under  Laptops  are  48

# %%
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}

print("Welcome to Yoshops.com")
print("\n\nPlease select the correct option finding the number of products on any webpage of Yoshops.com")
print("\n\nEnter 1 if your product lies into the main category of yoshops.com")
print("\n\nEnter 2 if your product lies into the sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat)")
print("\n\nEnter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat>sub_sub_cat)")

choice = int(input("\n\nEnter your choice from the given available options : "))
print("\n\nYou have select option ",choice)

def yoshops_product_count(choice):
    if choice == 1:
        url = input("\n\nEnter the url of the webpage of main category of Yoshops.com : ")
        response = requests.get(url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[1]:
            c.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the category of",c[0],"under Yoshops.com")
        print("The number of products available under ",c[0]," are ",len(y))
        
    elif choice == 2:
        sub_url = input("\n\nEnter the url of the webpage of subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[2]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[1]:
            e.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Subcategory of",c[0],"under Yoshops.com")
        print("The number of products available under ",e[0],">",c[0]," are ",len(y))
        
    elif choice == 3:
        sub_sub_url = input("\n\nEnter the url of the webpage of subcategory under some subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[3]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[2]:
            e.append(i)
        f = []
        for i in d[1]:
            f.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Sub - Subcategory of",c[0],"\nwhich is a Subcategory of",e[0] ,"\nwhich in turn is a sub category of",f[0],"which is category available under Yoshops.com")
        print("The number of products available under ",f[0],">",e[0],">",c[0]," are ",len(y))
        
    else:
        print("\n\nYou have entered a false choice. Please go through the available options and try again")
yoshops_product_count(choice)
# Out:
# Welcome to Yoshops.com
#
#
# Pease select the correct option finding the number of products on any webpage of Yoshops.com
#
#
# Enter 1 if your product lies into the main category of yoshops.com
#
#
# Enter 2 if your product lies into the sub-category of some main category of yoshops.com
# like (main_cat>sub_cat)
#
#
# Enter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com
# like (main_cat>sub_cat>sub_sub_cat)
#
#
# Enter your choice from the given available options : 2
#
#
# You have select option  2
#
#
# Enter the url of the webpage of subcategory under some main category of Yoshops.com : https://yoshops.com/t/books--bags
# The number of products in the given url are :  17
# They belong to the Subcategory of Bags under Yoshops.com
# The number of products available under  Accessories > Bags  are  17

# %%
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}

print("Welcome to Yoshops.com")
print("\n\nPlease select the correct option finding the number of products on any webpage of Yoshops.com")
print("\n\nEnter 1 if your product lies into the main category of yoshops.com")
print("\n\nEnter 2 if your product lies into the sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat)")
print("\n\nEnter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat>sub_sub_cat)")

choice = int(input("\n\nEnter your choice from the given available options : "))
print("\n\nYou have select option ",choice)

def yoshops_product_count(choice):
    if choice == 1:
        url = input("\n\nEnter the url of the webpage of main category of Yoshops.com : ")
        response = requests.get(url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[1]:
            c.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the category of",c[0],"under Yoshops.com")
        print("The number of products available under ",c[0]," are ",len(y))
        
    elif choice == 2:
        sub_url = input("\n\nEnter the url of the webpage of subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[2]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[1]:
            e.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Subcategory of",c[0],"under Yoshops.com")
        print("The number of products available under ",e[0],">",c[0]," are ",len(y))
        
    elif choice == 3:
        sub_sub_url = input("\n\nEnter the url of the webpage of subcategory under some subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[3]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[2]:
            e.append(i)
        f = []
        for i in d[1]:
            f.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Sub - Subcategory of",c[0],"\nwhich is a Subcategory of",e[0] ,"\nwhich in turn is a sub category of",f[0],"which is category available under Yoshops.com")
        print("The number of products available under ",f[0],">",e[0],">",c[0]," are ",len(y))
        
    else:
        print("\n\nYou have entered a false choice. Please go through the available options and try again")
yoshops_product_count(choice)
# Out:
# Welcome to Yoshops.com
#
#
# Pease select the correct option finding the number of products on any webpage of Yoshops.com
#
#
# Enter 1 if your product lies into the main category of yoshops.com
#
#
# Enter 2 if your product lies into the sub-category of some main category of yoshops.com
# like (main_cat>sub_cat)
#
#
# Enter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com
# like (main_cat>sub_cat>sub_sub_cat)
#
#
# Enter your choice from the given available options : 3
#
#
# You have select option  3
#
#
# Enter the url of the webpage of subcategory under some subcategory under some main category of Yoshops.com : https://yoshops.com/t/teacher-sponsorship
# The number of products in the given url are :  8
# They belong to the Sub - Subcategory of Teacher Sponsorship
# which is a Subcategory of Sponsorship Marketing
# which in turn is a sub category of Services which is category available under Yoshops.com
# The number of products available under  Services > Sponsorship Marketing > Teacher Sponsorship  are  8

# %%
import requests
from bs4 import BeautifulSoup
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}

print("Welcome to Yoshops.com")
print("\n\nPlease select the correct option finding the number of products on any webpage of Yoshops.com")
print("\n\nEnter 1 if your product lies into the main category of yoshops.com")
print("\n\nEnter 2 if your product lies into the sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat)")
print("\n\nEnter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com \nlike (main_cat>sub_cat>sub_sub_cat)")

choice = int(input("\n\nEnter your choice from the given available options : "))
print("\n\nYou have select option ",choice)

def yoshops_product_count(choice):
    if choice == 1:
        url = input("\n\nEnter the url of the webpage of main category of Yoshops.com : ")
        response = requests.get(url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[1]:
            c.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the category of",c[0],"under Yoshops.com")
        print("The number of products available under ",c[0]," are ",len(y))
        
    elif choice == 2:
        sub_url = input("\n\nEnter the url of the webpage of subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[2]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[1]:
            e.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Subcategory of",c[0],"under Yoshops.com")
        print("The number of products available under ",e[0],">",c[0]," are ",len(y))
        
    elif choice == 3:
        sub_sub_url = input("\n\nEnter the url of the webpage of subcategory under some subcategory under some main category of Yoshops.com : ")
        response = requests.get(sub_sub_url,headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        x = []
        y = []
        for i in soup.find_all('div', class_='product-thumb-inner'):
            x.append(i)
        for j in x:
            y.append(j.find_all('img'))
        for i in soup.find_all('ol'):
            b = i.find_all('li')
        c=[]
        for i in b[3]:
            c.append(i)
        for i in soup.find_all('ol'):
            d = i.find_all('a')
        e = []
        for i in d[2]:
            e.append(i)
        f = []
        for i in d[1]:
            f.append(i)
        print("The number of products in the given url are : ",len(y),"\nThey belong to the Sub - Subcategory of",c[0],"\nwhich is a Subcategory of",e[0] ,"\nwhich in turn is a sub category of",f[0],"which is category available under Yoshops.com")
        print("The number of products available under ",f[0],">",e[0],">",c[0]," are ",len(y))
        
    else:
        print("\n\nYou have entered a false choice. Please go through the available options and try again")
yoshops_product_count(choice)
# Out:
# Welcome to Yoshops.com
#
#
# Pease select the correct option finding the number of products on any webpage of Yoshops.com
#
#
# Enter 1 if your product lies into the main category of yoshops.com
#
#
# Enter 2 if your product lies into the sub-category of some main category of yoshops.com
# like (main_cat>sub_cat)
#
#
# Enter 3 if your product lies into sub-category of a sub-category of some main category of yoshops.com
# like (main_cat>sub_cat>sub_sub_cat)
#
#
# Enter your choice from the given available options : 5
#
#
# You have select option  5
#
#
# You have entered a false choice. Please go through the available options and try again
